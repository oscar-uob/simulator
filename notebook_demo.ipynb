# %% [markdown]
# Simulator demo
# =============
#
# This notebook demonstrates how to use the `Simulation` class to produce a plot of a simulation of an epidemic.
#
# The key point is the line
# ```python
# sim = Simulation(10, 10, recovery=0.1, infection=0.2, death=0.05)
# ```
# which sets the simulation parameters.
#
# If a person is at $(i, j)$ and has state $M_{ij}$ then the probability that they will get infected is given by
# $$
# P_{ij} = \sum_{nei
# $$

# %%
from simulator.sir import Simulation
from simulator.plot import plot_simulation
import matplotlib.pyplot as plt

sim = Simulation(10, 10, recovery=0.1, infection=0.2, death=0.05)
sim.infect_randomly(3)  # infect three people (chosen randomly)
fig = plot_simulation(sim, 100)

# %%
sim = Simulation(100, 100, recovery=0.1, infection=0.2, death=0.05)
sim.infect_randomly(10)  # infect three people (chosen randomly)
fig = plot_simulation(sim, 100)
